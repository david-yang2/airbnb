# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("AB_NYC_2019.csv")

# %%
data
# Out:
#              id                                               name    host_id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 1          2595                              Skylit Midtown Castle       2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 3          3831                    Cozy Entire Floor of Brownstone       4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099          Large Cozy 1 BR Apartment In Midtown East       7322
# 6          5121                                    BlissArtsSpace!       7356
# 7          5178                   Large Furnished Room Near B'way        8967
# 8          5203                 Cozy Clean Guest Room - Family Apt       7490
# 9          5238                 Cute & Cozy Lower East Side 1 bdrm       7549
# 10         5295                   Beautiful 1br on Upper West Side       7702
# ...

# %%
data.head(2)
# Out:
#      id                                name  host_id host_name  \
# 0  2539  Clean & quiet apt home by the park     2787      John
# 1  2595               Skylit Midtown Castle     2845  Jennifer
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355

# %%
data.room_type
# Out:
# 0           Private room
# 1        Entire home/apt
# 2           Private room
# 3        Entire home/apt
# 4        Entire home/apt
# 5        Entire home/apt
# 6           Private room
# 7           Private room
# 8           Private room
# 9        Entire home/apt
# 10       Entire home/apt
# 11          Private room
# 12          Private room
# 13          Private room
# 14       Entire home/apt
# 15       Entire home/apt
# 16       Entire home/apt
# 17          Private room
# 18       Entire home/apt
# 19       Entire home/apt
# 20       Entire home/apt
# 21          Private room
# 22          Private room
# 23          Private room
# 24       Entire home/apt
# 25          Private room
# 26          Private room
# 27       Entire home/apt
# 28          Private room
# 29       Entire home/apt
#               ...
# 48865       Private room
# 48866    Entire home/apt
# 48867        Shared room
# 48868        Shared room
# 48869       Private room
# 48870    Entire home/apt
# ...

# %%
data.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
data.neighbourhood_group.unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
data.neighbourhood_group.plot

# %%
neighbourhood = data.neighbourhood_group

# %%
type(neighbourhood)
# Out:
# pandas.core.series.Series

# %%
neighbourhood.plot
plt.show()

# %%
plt.plot(data.room_type)

# %%
data.room_type.unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
type_of_room = list(data.room_type.unique())

# %%
type_of_room
# Out:
# ['Private room', 'Entire home/apt', 'Shared room']

# %%
plt.plot(data.price)

# %%
data.price.describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
data[data.price<100]
# Out:
#              id                                               name    host_id  \
# 3          3831                    Cozy Entire Floor of Brownstone       4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 6          5121                                    BlissArtsSpace!       7356
# 7          5178                   Large Furnished Room Near B'way        8967
# 8          5203                 Cozy Clean Guest Room - Family Apt       7490
# 11         5441                    Central Manhattan/near Broadway       7989
# 12         5803     Lovely Room 1, Garden, Best Area, Legal rental       9744
# 13         6021   Wonderful Guest Bedroom in Manhattan for SINGLES      11528
# 18         7726    Hip Historic Brownstone Apartment with Backyard      20950
# 22         8025                           CBG Helps Haiti Room#2.5      22486
# 25         8505                 Sunny Bedroom Across Prospect Park      25326
# ...

# %%
data.reviews_per_month
# Out:
# 0        0.21
# 1        0.38
# 2         NaN
# 3        4.64
# 4        0.10
# 5        0.59
# 6        0.40
# 7        3.47
# 8        0.99
# 9        1.33
# 10       0.43
# 11       1.50
# 12       1.34
# 13       0.91
# 14       0.22
# 15       1.20
# 16       1.72
# 17       2.12
# 18       4.44
# 19        NaN
# 20       0.07
# 21       1.09
# 22       0.37
# 23       0.61
# 24       0.73
# 25       1.37
# 26        NaN
# 27       0.49
# 28       1.11
# 29       0.24
#          ...
# 48865     NaN
# 48866     NaN
# 48867     NaN
# 48868     NaN
# 48869     NaN
# 48870     NaN
# 48871     NaN
# 48872     NaN
# 48873     NaN
# 48874     NaN
# 48875     NaN
# 48876     NaN
# 48877     NaN
# 48878     NaN
# 48879     NaN
# 48880     NaN
# 48881     NaN
# 48882     NaN
# 48883     NaN
# 48884     NaN
# 48885     NaN
# 48886     NaN
# 48887     NaN
# 48888     NaN
# 48889     NaN
# 48890     NaN
# 48891     NaN
# 48892     NaN
# 48893     NaN
# 48894     NaN
# ...

# %%
test = data.fillna(0)

# %%
test[test.price<100]
# Out:
#              id                                               name    host_id  \
# 3          3831                    Cozy Entire Floor of Brownstone       4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 6          5121                                    BlissArtsSpace!       7356
# 7          5178                   Large Furnished Room Near B'way        8967
# 8          5203                 Cozy Clean Guest Room - Family Apt       7490
# 11         5441                    Central Manhattan/near Broadway       7989
# 12         5803     Lovely Room 1, Garden, Best Area, Legal rental       9744
# 13         6021   Wonderful Guest Bedroom in Manhattan for SINGLES      11528
# 18         7726    Hip Historic Brownstone Apartment with Backyard      20950
# 22         8025                           CBG Helps Haiti Room#2.5      22486
# 25         8505                 Sunny Bedroom Across Prospect Park      25326
# ...

# %%
test[test.price<100]
# Out:
#              id                                               name    host_id  \
# 3          3831                    Cozy Entire Floor of Brownstone       4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 6          5121                                    BlissArtsSpace!       7356
# 7          5178                   Large Furnished Room Near B'way        8967
# 8          5203                 Cozy Clean Guest Room - Family Apt       7490
# 11         5441                    Central Manhattan/near Broadway       7989
# 12         5803     Lovely Room 1, Garden, Best Area, Legal rental       9744
# 13         6021   Wonderful Guest Bedroom in Manhattan for SINGLES      11528
# 18         7726    Hip Historic Brownstone Apartment with Backyard      20950
# 22         8025                           CBG Helps Haiti Room#2.5      22486
# 25         8505                 Sunny Bedroom Across Prospect Park      25326
# ...

# %%
test[test.price>500]
# Out:
#              id                                               name    host_id  \
# 85        19601                perfect for a family or small group      74303
# 299       68974                 Unique spacious loft on the Bowery     281229
# 345       89427                               The Brooklyn Waverly     116599
# 365      103311                  2 BR w/ Terrace @ Box House Hotel     417504
# 496      174966              Luxury 2Bed/2.5Bath Central Park View     836168
# 653      248871  4 BEDROOM -2BATHRM WEST VILLAGE DUPLEX  TOWNHOUSE     605463
# 662      250801                 Heart & Soul of Greenwich Village     1314834
# 684      254168                      2 BR Duplex @ Box House Hotel     417504
# 691      256328          Luxury Chelsea Townhouse at the High Line    1347034
# 762      273190          6 Bedroom Landmark West Village Townhouse     605463
# 780      279857  #1 Yellow Block BnB/see at Net Flix Show Stay ...    1420300
# ...

# %%
test.neighbourhood
# Out:
# 0                Kensington
# 1                   Midtown
# 2                    Harlem
# 3              Clinton Hill
# 4               East Harlem
# 5               Murray Hill
# 6        Bedford-Stuyvesant
# 7            Hell's Kitchen
# 8           Upper West Side
# 9                 Chinatown
# 10          Upper West Side
# 11           Hell's Kitchen
# 12              South Slope
# 13          Upper West Side
# 14             West Village
# 15             Williamsburg
# 16              Fort Greene
# 17                  Chelsea
# 18            Crown Heights
# 19              East Harlem
# 20             Williamsburg
# 21               Park Slope
# 22               Park Slope
# 23               Park Slope
# 24       Bedford-Stuyvesant
# 25          Windsor Terrace
# 26                   Inwood
# 27           Hell's Kitchen
# 28                   Inwood
# 29             East Village
#                 ...
# 48865                Inwood
# 48866             Briarwood
# ...

# %%
test.neighbourhood_group
# Out:
# 0         Brooklyn
# 1        Manhattan
# 2        Manhattan
# 3         Brooklyn
# 4        Manhattan
# 5        Manhattan
# 6         Brooklyn
# 7        Manhattan
# 8        Manhattan
# 9        Manhattan
# 10       Manhattan
# 11       Manhattan
# 12        Brooklyn
# 13       Manhattan
# 14       Manhattan
# 15        Brooklyn
# 16        Brooklyn
# 17       Manhattan
# 18        Brooklyn
# 19       Manhattan
# 20        Brooklyn
# 21        Brooklyn
# 22        Brooklyn
# 23        Brooklyn
# 24        Brooklyn
# 25        Brooklyn
# 26       Manhattan
# 27       Manhattan
# 28       Manhattan
# 29       Manhattan
#            ...
# 48865    Manhattan
# 48866       Queens
# 48867     Brooklyn
# 48868     Brooklyn
# 48869     Brooklyn
# 48870     Brooklyn
# 48871    Manhattan
# 48872    Manhattan
# 48873     Brooklyn
# 48874    Manhattan
# 48875    Manhattan
# 48876    Manhattan
# 48877     Brooklyn
# 48878       Queens
# 48879     Brooklyn
# 48880     Brooklyn
# ...

# %%
test.neighbourhood_group.unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
neighborhoods = test.neighbourhood_group.unique()

# %%
test.reviews_per_month<3
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4         True
# 5         True
# 6         True
# 7        False
# 8         True
# 9         True
# 10        True
# 11        True
# 12        True
# 13        True
# 14        True
# 15        True
# 16        True
# 17        True
# 18       False
# 19        True
# 20        True
# 21        True
# 22        True
# 23        True
# 24        True
# 25        True
# 26        True
# 27        True
# 28        True
# 29        True
#          ...
# 48865     True
# 48866     True
# 48867     True
# 48868     True
# 48869     True
# 48870     True
# 48871     True
# 48872     True
# 48873     True
# 48874     True
# 48875     True
# 48876     True
# 48877     True
# 48878     True
# 48879     True
# 48880     True
# 48881     True
# 48882     True
# 48883     True
# 48884     True
# 48885     True
# 48886     True
# 48887     True
# 48888     True
# 48889     True
# 48890     True
# 48891     True
# ...

# %%
test.reviews_per_month>6
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 48865    False
# 48866    False
# 48867    False
# 48868    False
# 48869    False
# 48870    False
# 48871    False
# 48872    False
# 48873    False
# 48874    False
# 48875    False
# 48876    False
# 48877    False
# 48878    False
# 48879    False
# 48880    False
# 48881    False
# 48882    False
# 48883    False
# 48884    False
# 48885    False
# 48886    False
# 48887    False
# 48888    False
# 48889    False
# 48890    False
# 48891    False
# ...

# %%
less_than_three = test[test.reviews_per_month<3]

# %%
less_than_three
# Out:
#              id                                               name    host_id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 1          2595                              Skylit Midtown Castle       2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099          Large Cozy 1 BR Apartment In Midtown East       7322
# 6          5121                                    BlissArtsSpace!       7356
# 8          5203                 Cozy Clean Guest Room - Family Apt       7490
# 9          5238                 Cute & Cozy Lower East Side 1 bdrm       7549
# 10         5295                   Beautiful 1br on Upper West Side       7702
# 11         5441                    Central Manhattan/near Broadway       7989
# 12         5803     Lovely Room 1, Garden, Best Area, Legal rental       9744
# ...

# %%
long_listings = test[test.minimum_nights > 7]

# %%
long_listings
# Out:
#              id                                               name    host_id  \
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 6          5121                                    BlissArtsSpace!       7356
# 14         6090                      West Village Nest - Superhost      11975
# 27         9357                               Midtown Pied-a-terre      30193
# 29         9657                   Modern 1 BR / NYC / EAST VILLAGE      21904
# 36        11452                        Clean and Quiet in Brooklyn       7355
# 45        12627  Entire apartment in central Brooklyn neighborh...      49670
# 55        14377                   Williamsburg 1 bedroom Apartment      56512
# 59        15341      **Bright Nolita Apt w Doorman/Elevators/Gym**      60049
# 61        15396                 Sunny & Spacious Chelsea Apartment      60278
# 63        16326         Comfortable 4-bedroom apt in family house.      63588
# ...

# %%
short_listings = test[test.minimum_nights > 7]

# %%
short_listings
# Out:
#              id                                               name    host_id  \
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 6          5121                                    BlissArtsSpace!       7356
# 14         6090                      West Village Nest - Superhost      11975
# 27         9357                               Midtown Pied-a-terre      30193
# 29         9657                   Modern 1 BR / NYC / EAST VILLAGE      21904
# 36        11452                        Clean and Quiet in Brooklyn       7355
# 45        12627  Entire apartment in central Brooklyn neighborh...      49670
# 55        14377                   Williamsburg 1 bedroom Apartment      56512
# 59        15341      **Bright Nolita Apt w Doorman/Elevators/Gym**      60049
# 61        15396                 Sunny & Spacious Chelsea Apartment      60278
# 63        16326         Comfortable 4-bedroom apt in family house.      63588
# ...

# %%
seasonal = test[test.availability_365 > 90]

# %%
seasonal
# Out:
#              id                                               name    host_id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 1          2595                              Skylit Midtown Castle       2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 3          3831                    Cozy Entire Floor of Brownstone       4869
# 5          5099          Large Cozy 1 BR Apartment In Midtown East       7322
# 7          5178                   Large Furnished Room Near B'way        8967
# 9          5238                 Cute & Cozy Lower East Side 1 bdrm       7549
# 12         5803     Lovely Room 1, Garden, Best Area, Legal rental       9744
# 13         6021   Wonderful Guest Bedroom in Manhattan for SINGLES      11528
# 16         7097                  Perfect for Your Parents + Garden      17571
# 19         7750                  Huge 2 BR Upper East  Cental Park      17985
# ...

# %%
test.room_type.unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
private_room = test.room_type.unique()[0]

# %%
entire_home_apt = test.room_type.unique()[1]

# %%
shared_room = test.room_type.unique()[2]

# %%
test.neighbourhood_group
# Out:
# 0         Brooklyn
# 1        Manhattan
# 2        Manhattan
# 3         Brooklyn
# 4        Manhattan
# 5        Manhattan
# 6         Brooklyn
# 7        Manhattan
# 8        Manhattan
# 9        Manhattan
# 10       Manhattan
# 11       Manhattan
# 12        Brooklyn
# 13       Manhattan
# 14       Manhattan
# 15        Brooklyn
# 16        Brooklyn
# 17       Manhattan
# 18        Brooklyn
# 19       Manhattan
# 20        Brooklyn
# 21        Brooklyn
# 22        Brooklyn
# 23        Brooklyn
# 24        Brooklyn
# 25        Brooklyn
# 26       Manhattan
# 27       Manhattan
# 28       Manhattan
# 29       Manhattan
#            ...
# 48865    Manhattan
# 48866       Queens
# 48867     Brooklyn
# 48868     Brooklyn
# 48869     Brooklyn
# 48870     Brooklyn
# 48871    Manhattan
# 48872    Manhattan
# 48873     Brooklyn
# 48874    Manhattan
# 48875    Manhattan
# 48876    Manhattan
# 48877     Brooklyn
# 48878       Queens
# 48879     Brooklyn
# 48880     Brooklyn
# ...

# %%
test[test.neighbourhood_group == "Brooklyn"]
# Out:
#              id                                               name    host_id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 3          3831                    Cozy Entire Floor of Brownstone       4869
# 6          5121                                    BlissArtsSpace!       7356
# 12         5803     Lovely Room 1, Garden, Best Area, Legal rental       9744
# 15         6848                   Only 2 stops to Manhattan studio      15991
# 16         7097                  Perfect for Your Parents + Garden      17571
# 18         7726    Hip Historic Brownstone Apartment with Backyard      20950
# 20         7801                   Sweet and Spacious Brooklyn Loft      21207
# 21         8024                     CBG CtyBGd HelpsHaiti rm#1:1-4      22486
# 22         8025                           CBG Helps Haiti Room#2.5      22486
# 23         8110                              CBG Helps Haiti Rm #2      22486
# ...

# %%
test[test.neighbourhood_group == "Manhattan"]
# Out:
#              id                                               name    host_id  \
# 1          2595                              Skylit Midtown Castle       2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099          Large Cozy 1 BR Apartment In Midtown East       7322
# 7          5178                   Large Furnished Room Near B'way        8967
# 8          5203                 Cozy Clean Guest Room - Family Apt       7490
# 9          5238                 Cute & Cozy Lower East Side 1 bdrm       7549
# 10         5295                   Beautiful 1br on Upper West Side       7702
# 11         5441                    Central Manhattan/near Broadway       7989
# 13         6021   Wonderful Guest Bedroom in Manhattan for SINGLES      11528
# 14         6090                      West Village Nest - Superhost      11975
# ...

# %%
Queens = test[test.neighbourhood_group == "Queens"]

# %%
Queens
# Out:
#              id                                               name    host_id  \
# 46        12937  1 Stop fr. Manhattan! Private Suite,Landmark B...      50124
# 77        18198                              Little King of Queens      70091
# 143       32363                 Fully Furnished Basement Apartment     140025
# 161       39593            A room w/ a Manhattan view, longer stay     110506
# 181       45910                 Beautiful Queens Brownstone! - 5BR     204539
# 196       51850                              ( F) Excellent/Pvt Rm      27848
# 199       53469                      cozy studio with parking spot     204539
# 200       53470                 Clean and convenient 2BR apartment     204539
# 201       53477                                3 floors of luxury!     204539
# 218       57166                                    Elegant NYC Pad     272006
# 229       59121                  Nice, clean, safe, convenient 3BR     204539
# ...

# %%
Staten_Island = test[test.neighbourhood_group == "Staten Island"]

# %%
test.neighbourhood_group.unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
Staten_Island
# Out:
#              id                                               name    host_id  \
# 169       42882                          New York room with a view     185978
# 249       62452                     A SpeciaL!! Private Room in NY     303939
# 250       62461                        B NYC Staten Alternative...     303939
# 251       62787                        C Private Room By The Ferry     303939
# 256       63320                 D Private Che@p Room 2 Explore NYC     303939
# 571      214917                 New Clean Spacious Bed & Breakfast    1109658
# 598      225976                 Sunny cozy multileveled apartment!    1177947
# 702      258838                       Oceanview,close to Manhattan    1360198
# 703      258876                Affordable rooms,all transportation    1360198
# 704      259946                   Budget stay, near transportation    1360198
# 866      310272       Private Room in Artist's Home, Stapleton, SI    1390555
# ...
